# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
import numpy as np
from matplotlib import colors
import matplotlib
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as shc
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# # Read the data

# %%
heart_hierarchical_df = pd.read_csv('D:\\\\BelajarML\\\\praktikkum\\\\pertemuan4\\\\heart_failure_clinical_records_dataset.csv')

# %%
heart_hierarchical_df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %% [markdown]
# # Begin Data Preprocessing

# %%
heart_hierarchical_df[heart_hierarchical_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [age, anaemia, creatinine_phosphokinase, diabetes, ejection_fraction, high_blood_pressure, platelets, serum_creatinine, serum_sodium, sex, smoking, time, DEATH_EVENT]
# Index: []

# %%
heart_hierarchical_df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
heart_hierarchical_df.info
# Out:
# <bound method DataFrame.info of       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
# ...

# %% [markdown]
# # Pemilihan Clustering Atribute

# %%
heart_hierarchical_df.head(10)
heart_hierarchical_df['serum_sodium']
# Out:
# 0      130
# 1      136
# 2      129
# 3      137
# 4      116
#       ...
# 294    143
# 295    139
# 296    138
# 297    140
# 298    136
# Name: serum_sodium, Length: 299, dtype: int64

# %%
heart_hierarchical_df['high_blood_pressure']
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 294    1
# 295    0
# 296    0
# 297    0
# 298    0
# Name: high_blood_pressure, Length: 299, dtype: int64

# %%
heart_hierarchical_df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
heart_hierarchical_df.info
# Out:
# <bound method DataFrame.info of       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
# ...

# %%
heart_hierarchical_df.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %%
heart_hierarchical_df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
sns.lineplot(heart_hierarchical_df,x='age',y='sex')
# Out:
# <Axes: xlabel='age', ylabel='sex'>

# %%
clean_heart_df = heart_hierarchical_df
clean_heart_df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %% [markdown]
# # Scaling data  using Min Max

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
mms = MinMaxScaler()
clean_heart_df = mms.fit_transform(heart_hierarchical_df)
clean_heart_df  = pd.DataFrame(clean_heart_df,columns=heart_hierarchical_df.columns)
clean_heart_df
# Out:
#           age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    0.636364      0.0                  0.071319       0.0           0.090909
# 1    0.272727      0.0                  1.000000       0.0           0.363636
# 2    0.454545      0.0                  0.015693       0.0           0.090909
# 3    0.181818      1.0                  0.011227       0.0           0.090909
# 4    0.454545      1.0                  0.017479       1.0           0.090909
# ..        ...      ...                       ...       ...                ...
# 294  0.400000      0.0                  0.004848       1.0           0.363636
# 295  0.272727      0.0                  0.229268       0.0           0.363636
# 296  0.090909      0.0                  0.259888       1.0           0.696970
# 297  0.090909      0.0                  0.304925       0.0           0.363636
# 298  0.181818      0.0                  0.022072       0.0           0.469697
#
# ...

# %%
clean_heart_df
# Out:
#           age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    0.636364      0.0                  0.071319       0.0           0.090909
# 1    0.272727      0.0                  1.000000       0.0           0.363636
# 2    0.454545      0.0                  0.015693       0.0           0.090909
# 3    0.181818      1.0                  0.011227       0.0           0.090909
# 4    0.454545      1.0                  0.017479       1.0           0.090909
# ..        ...      ...                       ...       ...                ...
# 294  0.400000      0.0                  0.004848       1.0           0.363636
# 295  0.272727      0.0                  0.229268       0.0           0.363636
# 296  0.090909      0.0                  0.259888       1.0           0.696970
# 297  0.090909      0.0                  0.304925       0.0           0.363636
# 298  0.181818      0.0                  0.022072       0.0           0.469697
#
# ...

# %%
clean_heart_df.corr()
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.088006                 -0.081584
# anaemia                   0.088006  1.000000                 -0.190741
# creatinine_phosphokinase -0.081584 -0.190741                  1.000000
# diabetes                 -0.101012 -0.012729                 -0.009639
# ejection_fraction         0.060098  0.031557                 -0.044080
# high_blood_pressure       0.093289  0.038182                 -0.070590
# platelets                -0.052354 -0.043786                  0.024463
# serum_creatinine          0.159187  0.052174                 -0.016408
# serum_sodium             -0.045966  0.041882                  0.059550
# sex                       0.065430 -0.094769                  0.079791
# smoking                   0.018668 -0.107290                  0.002421
# time                     -0.224068 -0.141414                 -0.009346
# ...

# %%
clean_heart_df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean     0.378798    0.431438                  0.071299    0.418060
# std      0.216269    0.496107                  0.123793    0.494067
# min      0.000000    0.000000                  0.000000    0.000000
# 25%      0.200000    0.000000                  0.011929    0.000000
# 50%      0.363636    0.000000                  0.028961    0.000000
# 75%      0.545455    1.000000                  0.071319    1.000000
# max      1.000000    1.000000                  1.000000    1.000000
#
#        ejection_fraction  high_blood_pressure   platelets  serum_creatinine  \
# count         299.000000           299.000000  299.000000        299.000000
# mean            0.364903             0.351171    0.288833          0.100436
# std             0.179316             0.478136    0.118565          0.116237
# ...

# %% [markdown]
# # Find correlation between features

# %%
plt.figure(figsize=(10,10))
sns.heatmap(clean_heart_df.corr() , annot=True)
# Out:
# <Axes: >

# %%
corr_df = clean_heart_df[['age','high_blood_pressure' ,'diabetes','serum_creatinine','creatinine_phosphokinase','serum_sodium']].copy()
corr_df.corr()
# Out:
#                                age  high_blood_pressure  diabetes  \
# age                       1.000000             0.093289 -0.101012
# high_blood_pressure       0.093289             1.000000 -0.012732
# diabetes                 -0.101012            -0.012732  1.000000
# serum_creatinine          0.159187            -0.004935 -0.046975
# creatinine_phosphokinase -0.081584            -0.070590 -0.009639
# serum_sodium             -0.045966             0.037109 -0.089551
#
#                           serum_creatinine  creatinine_phosphokinase  \
# age                               0.159187                 -0.081584
# high_blood_pressure              -0.004935                 -0.070590
# diabetes                         -0.046975                 -0.009639
# serum_creatinine                  1.000000                 -0.016408
# creatinine_phosphokinase         -0.016408                  1.000000
# serum_sodium                     -0.189095                  0.059550
#
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data=corr_df.corr(), annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 10))

sns.displot(heart_hierarchical_df['age'], kind='kde', color='red')

# %%
list(heart_hierarchical_df.columns)
# Out:
# ['age',
#  'anaemia',
#  'creatinine_phosphokinase',
#  'diabetes',
#  'ejection_fraction',
#  'high_blood_pressure',
#  'platelets',
#  'serum_creatinine',
#  'serum_sodium',
#  'sex',
#  'smoking',
#  'time',
#  'DEATH_EVENT']

# %%
sns.scatterplot(heart_hierarchical_df,x='age',y='serum_sodium')
# Out:
# <Axes: xlabel='age', ylabel='serum_sodium'>

# %%
def boxplot(column):
    sns.boxplot(data=clean_heart_df, x=heart_hierarchical_df[f"{column}"])
    plt.title(f"Boxplot of Iris Dataset {column}")
    plt.show()

# %%
behaviour = ['age']
for i in range(len(behaviour)):
    boxplot(column=behaviour[i])

# %%
heart_hierarchical_df['age'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      75.0
# 1      55.0
# 2      65.0
# 3      50.0
# 4      65.0
#        ...
# 294    62.0
# 295    55.0
# 296    45.0
# 297    45.0
# 298    50.0
# Name: age, Length: 299, dtype: float64>

# %%
sns.barplot(data=heart_hierarchical_df,x='high_blood_pressure',y='age')
# Out:
# <Axes: xlabel='high_blood_pressure', ylabel='age'>

# %%
sns.boxenplot(data=heart_hierarchical_df, x='high_blood_pressure' , y='age')
# Out:
# <Axes: xlabel='high_blood_pressure', ylabel='age'>

# %%
sns.ecdfplot(data=heart_hierarchical_df,x='age')
# Out:
# <Axes: xlabel='age', ylabel='Proportion'>

# %%
heart_failre_prepro = pd.DataFrame(clean_heart_df)
heart_failre_prepro.to_csv('heart_failure_prepro_data.csv', index=False)
heart_failre_prepro
# Out:
#           age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    0.636364      0.0                  0.071319       0.0           0.090909
# 1    0.272727      0.0                  1.000000       0.0           0.363636
# 2    0.454545      0.0                  0.015693       0.0           0.090909
# 3    0.181818      1.0                  0.011227       0.0           0.090909
# 4    0.454545      1.0                  0.017479       1.0           0.090909
# ..        ...      ...                       ...       ...                ...
# 294  0.400000      0.0                  0.004848       1.0           0.363636
# 295  0.272727      0.0                  0.229268       0.0           0.363636
# 296  0.090909      0.0                  0.259888       1.0           0.696970
# 297  0.090909      0.0                  0.304925       0.0           0.363636
# 298  0.181818      0.0                  0.022072       0.0           0.469697
#
# ...
