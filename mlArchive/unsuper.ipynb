# %%
import pandas as pd 

df = pd.read_csv('./dataset/dataslayer/test.csv')
df
# Out:
#            Id      Make    Vehicle Class Engine Size(L)      Cylinders  \
# 0      137142  CADILUXE         MID-SIZE            3.6            NaN
# 1      137143      FOLD  VAN - PASSENGER            3.7            6.0
# 2      137144     MITSU      SUV - SMALL            6.0            NaN
# 3      137145     LECUS         MID-SIZE            4.6            NaN
# 4      137146       BMV   SUV - STANDARD            4.4            8.0
# ...       ...       ...              ...            ...            ...
# 58771  195913       KIO      SUV - SMALL            3.3            NaN
# 58772  195914      FOLD      unspecified            1.6            4.0
# 58773  195915     CHEVO   SUV - STANDARD            3.5  unestablished
# 58774  195916      FOLD          unknown            5.0            8.0
# 58775  195917     ASURA      SUV - SMALL            3.5            6.0
#
#       Transmission Fuel Type Fuel Consumption City     Fuel Consumption Hwy  \
# ...

# %% [markdown]
# # Menghilangkan satuan

# %%
df['Fuel Consumption City'] = df['Fuel Consumption City'].str.extract('(\d+\.\d+|\d+)')
df
# Out:
#            Id      Make    Vehicle Class Engine Size(L)      Cylinders  \
# 0      137142  CADILUXE         MID-SIZE            3.6            NaN
# 1      137143      FOLD  VAN - PASSENGER            3.7            6.0
# 2      137144     MITSU      SUV - SMALL            6.0            NaN
# 3      137145     LECUS         MID-SIZE            4.6            NaN
# 4      137146       BMV   SUV - STANDARD            4.4            8.0
# ...       ...       ...              ...            ...            ...
# 58771  195913       KIO      SUV - SMALL            3.3            NaN
# 58772  195914      FOLD      unspecified            1.6            4.0
# 58773  195915     CHEVO   SUV - STANDARD            3.5  unestablished
# 58774  195916      FOLD          unknown            5.0            8.0
# 58775  195917     ASURA      SUV - SMALL            3.5            6.0
#
#       Transmission Fuel Type Fuel Consumption City Fuel Consumption Hwy  \
# ...

# %%
df['Fuel Consumption Hwy'] = df['Fuel Consumption Hwy'].str.extract('(\d+\.\d+|\d+)')
df
# Out:
#            Id      Make    Vehicle Class Engine Size(L)      Cylinders  \
# 0      137142  CADILUXE         MID-SIZE            3.6            NaN
# 1      137143      FOLD  VAN - PASSENGER            3.7            6.0
# 2      137144     MITSU      SUV - SMALL            6.0            NaN
# 3      137145     LECUS         MID-SIZE            4.6            NaN
# 4      137146       BMV   SUV - STANDARD            4.4            8.0
# ...       ...       ...              ...            ...            ...
# 58771  195913       KIO      SUV - SMALL            3.3            NaN
# 58772  195914      FOLD      unspecified            1.6            4.0
# 58773  195915     CHEVO   SUV - STANDARD            3.5  unestablished
# 58774  195916      FOLD          unknown            5.0            8.0
# 58775  195917     ASURA      SUV - SMALL            3.5            6.0
#
#       Transmission Fuel Type Fuel Consumption City Fuel Consumption Hwy  \
# ...

# %%
df['Fuel Consumption Comb'] = df['Fuel Consumption Comb'].str.extract('(\d+\.\d+|\d+)')
df
# Out:
#            Id      Make    Vehicle Class Engine Size(L)      Cylinders  \
# 0      137142  CADILUXE         MID-SIZE            3.6            NaN
# 1      137143      FOLD  VAN - PASSENGER            3.7            6.0
# 2      137144     MITSU      SUV - SMALL            6.0            NaN
# 3      137145     LECUS         MID-SIZE            4.6            NaN
# 4      137146       BMV   SUV - STANDARD            4.4            8.0
# ...       ...       ...              ...            ...            ...
# 58771  195913       KIO      SUV - SMALL            3.3            NaN
# 58772  195914      FOLD      unspecified            1.6            4.0
# 58773  195915     CHEVO   SUV - STANDARD            3.5  unestablished
# 58774  195916      FOLD          unknown            5.0            8.0
# 58775  195917     ASURA      SUV - SMALL            3.5            6.0
#
#       Transmission Fuel Type Fuel Consumption City Fuel Consumption Hwy  \
# ...

# %%
df['Cylinders'] = df['Cylinders'].str.extract('(\d+\.\d+|\d+)')
df.dropna()
# Out:
#            Id    Make         Vehicle Class Engine Size(L) Cylinders  \
# 1      137143    FOLD       VAN - PASSENGER            3.7       6.0
# 4      137146     BMV        SUV - STANDARD            4.4       8.0
# 5      137147   CHEVO            SUBCOMPACT            3.6       6.0
# 6      137148    FOLD       VAN - PASSENGER            3.5       6.0
# 7      137149   TOLVO        SUV - STANDARD            2.0       4.0
# ...       ...     ...                   ...            ...       ...
# 58768  195910  NIRRAN  PICKUP TRUCK - SMALL            4.0       6.0
# 58769  195911    JIPU           SUV - SMALL            2.4       4.0
# 58772  195914    FOLD           unspecified            1.6       4.0
# 58774  195916    FOLD               unknown            5.0       8.0
# 58775  195917   ASURA           SUV - SMALL            3.5       6.0
#
#       Transmission Fuel Type Fuel Consumption City Fuel Consumption Hwy  \
# ...

# %% [markdown]
# # Melihat tipe data

# %%
df.dtypes
# Out:
# Id                        int64
# Make                     object
# Vehicle Class            object
# Engine Size(L)           object
# Cylinders                object
# Transmission             object
# Fuel Type                object
# Fuel Consumption City    object
# Fuel Consumption Hwy     object
# Fuel Consumption Comb    object
# dtype: object

# %%
# Menghapus nilai NaN

# %% [markdown]
# Menghapus nilai NaN

# %%
df.dropna(inplace=True)
df
# Out:
#            Id   Make    Vehicle Class Engine Size(L)      Cylinders  \
# 1      137143   FOLD  VAN - PASSENGER            3.7            6.0
# 4      137146    BMV   SUV - STANDARD            4.4            8.0
# 5      137147  CHEVO       SUBCOMPACT            3.6            6.0
# 6      137148   FOLD  VAN - PASSENGER            3.5            6.0
# 7      137149  TOLVO   SUV - STANDARD            2.0            4.0
# ...       ...    ...              ...            ...            ...
# 58769  195911   JIPU      SUV - SMALL            2.4            4.0
# 58772  195914   FOLD      unspecified            1.6            4.0
# 58773  195915  CHEVO   SUV - STANDARD            3.5  unestablished
# 58774  195916   FOLD          unknown            5.0            8.0
# 58775  195917  ASURA      SUV - SMALL            3.5            6.0
#
#       Transmission Fuel Type Fuel Consumption City Fuel Consumption Hwy  \
# 1              AS6         X                 21.11                14.38
# ...
