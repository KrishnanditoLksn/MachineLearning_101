# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
import plotly.express as px
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import LeaveOneOut
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE
data_employee = pd.read_csv('./dataset/employee.csv')
data_employee
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
data_employee.describe()
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4653.000000
# mean      0.343864
# std       0.475047
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
data_employee.info
# Out:
# <bound method DataFrame.info of       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
data_employee.dropna()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
data_employee.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %% [markdown]
# Memvisualisasikan dalam bentuk Bar Chart

# %%
import plotly.express as px
fig1 = px.bar(data_employee ,x='Education' , title='Education Level Distribution')
fig1.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 import plotly.express as px
#       2 fig1 = px.bar(data_employee ,x='Education' , title='Education Level Distribution')
# ----> 3 fig1.show()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:3409, in BaseFigure.show(self, *args, **kwargs)
#    3376 """
#    3377 Show a figure using either the default renderer(s) or the renderer(s)
#    3378 specified by the renderer argument
#    (...)
#    3405 None
#    3406 """
#    3407 import plotly.io as pio
# -> 3409 return pio.show(self, *args, **kwargs)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
# ...

# %% [markdown]
# Memvisualisasikan ke bentuk histogram

# %%
fig2 = px.histogram(data_employee , x='JoiningYear' , title='Joining Year Distribution')
fig2.show()

for i in  range(2):
    print("whwhw")
# Out:
# <div>                            <div id="5c6b7fde-ca80-48ab-a799-8c54f3edf572" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c6b7fde-ca80-48ab-a799-8c54f3edf572")) {                    Plotly.newPlot(                        "5c6b7fde-ca80-48ab-a799-8c54f3edf572",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"JoiningYear=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[2017,2013,2014,2016,2017,2016,2015,2016,2016,2017,2012,2016,2018,2016,2012,2017,2014,2014,2015,2016,2012,2017,2017,2015,2017,2013,2016,2015,2013,2017,2013,2014,2018,2016,2017,2014,2012,2018,
# ...

# %%
data_employee.dtypes
# Out:
# Education                    object
# JoiningYear                   int64
# City                         object
# PaymentTier                   int64
# Age                           int64
# Gender                       object
# EverBenched                  object
# ExperienceInCurrentDomain     int64
# LeaveOrNot                    int64
# dtype: object

# %% [markdown]
# Check for null values

# %%
data_employee.isna().sum()
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64

# %% [markdown]
# unique values in object columns

# %%
data_employee.nunique() , data_employee.City.nunique() , data_employee.Gender.nunique() , data_employee.EverBenched.nunique()
# Out:
# (Education                     3
#  JoiningYear                   7
#  City                          3
#  PaymentTier                   3
#  Age                          20
#  Gender                        2
#  EverBenched                   2
#  ExperienceInCurrentDomain     8
#  LeaveOrNot                    2
#  dtype: int64,
#  3,
#  2,
#  2)

# %%
#Melabeli setiap kolom

# %%
data_employee.head()
# Out:
#    Education  JoiningYear  City  PaymentTier  Age  Gender  EverBenched  \
# 0          0         2017     0            3   34       1            0
# 1          0         2013     2            1   28       0            0
# 2          0         2014     1            3   38       0            0
# 3          1         2016     0            3   27       1            0
# 4          1         2017     2            3   24       1            1
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %% [markdown]
# # Visualization 3: Pie chart for Gender distribution

# %% [markdown]
# # Visualization 4: Box plot for Age distribution

# %% [markdown]
# # Visualization 5: Scatter plot for Experience vs Payment Tier

# %% [markdown]
# # Features, Labels

# %%
labelencoder = LabelEncoder()

cat_cols = [col for col in data_employee.select_dtypes(include='object').columns.tolist()]

# %% [markdown]
# # Train Test Split

# %%
cat_cols
# Out:
# []

# %%
label_cols = data_employee[cat_cols].apply(LabelEncoder().fit_transform)
label_cols
# Out:
# Series([], dtype: float64)
